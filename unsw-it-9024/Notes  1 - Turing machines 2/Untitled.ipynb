# %%
l = [1,2,3,4,5]

# %%
[str( number) for number in l]
# Out:
# ['1', '2', '3', '4', '5']

# %%
'|'.join([str(number) for number in l])
# Out:
# '1|2|3|4|5'

# %%
'|'+'|'.join([str(number) for number in l]) +'|'
# Out:
# '|1|2|3|4|5|'
